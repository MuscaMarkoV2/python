# %% [markdown]
# Wine Quality Data Set - contains 12 parameters which characterise the wine:
# fixed acidity
# volatile acidity
# citric acid
# residual sugar
# parametrul chlorides
# free sulfur dioxide
# total sulfur dioxide
# density
# pH
# sulphates
# alcohol
# quality (values between 0 and 10) - parameter to determinate
# The first 11 parameters can be used to classify wines into 11 categories, the category indicated by the quality parameter.
# For example, if the quality parameter takes the value 3, then wines with this quality are part of class 3.

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("wine.csv")

# %%
valori = data.values
print(valori)
# Out:
# [[ 7.4    0.7    0.    ...  0.56   9.4    5.   ]
#  [ 7.8    0.88   0.    ...  0.68   9.8    5.   ]
#  [ 7.8    0.76   0.04  ...  0.65   9.8    5.   ]
#  ...
#  [ 6.3    0.51   0.13  ...  0.75  11.     6.   ]
#  [ 5.9    0.645  0.12  ...  0.71  10.2    5.   ]
#  [ 6.     0.31   0.47  ...  0.66  11.     6.   ]]

# %%
x = valori[:, 0:11]
y = valori[:, 11]
print(x)
# Out:
# [[ 7.4    0.7    0.    ...  3.51   0.56   9.4  ]
#  [ 7.8    0.88   0.    ...  3.2    0.68   9.8  ]
#  [ 7.8    0.76   0.04  ...  3.26   0.65   9.8  ]
#  ...
#  [ 6.3    0.51   0.13  ...  3.42   0.75  11.   ]
#  [ 5.9    0.645  0.12  ...  3.57   0.71  10.2  ]
#  [ 6.     0.31   0.47  ...  3.39   0.66  11.   ]]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2)
model = LogisticRegression()

# %%
# 8. Antrenăm modelul
history = model.fit(
    x_train, y_train
)

print("\n🔔 Antrenament terminat!")
# Out:
# 🔔 Antrenament terminat!
# c:\Users\Alina\Desktop\programare\Phyton25\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
etichete_prezise = model.predict(x_test)

# %%
acuratete = model.score(x_test, y_test)
print(acuratete)
# Out:
# 0.571875

# %%
for i, et in enumerate(etichete_prezise):
    print(f"Eticheta reala:{y_test[i]}, eticheta prezisa:{et}")
# Out:
# Eticheta reala:5.0, eticheta prezisa:5.0
# Eticheta reala:7.0, eticheta prezisa:6.0
# Eticheta reala:7.0, eticheta prezisa:7.0
# Eticheta reala:6.0, eticheta prezisa:5.0
# Eticheta reala:4.0, eticheta prezisa:5.0
# Eticheta reala:6.0, eticheta prezisa:6.0
# Eticheta reala:5.0, eticheta prezisa:6.0
# Eticheta reala:7.0, eticheta prezisa:6.0
# Eticheta reala:6.0, eticheta prezisa:6.0
# Eticheta reala:7.0, eticheta prezisa:6.0
# Eticheta reala:5.0, eticheta prezisa:5.0
# Eticheta reala:6.0, eticheta prezisa:6.0
# Eticheta reala:6.0, eticheta prezisa:6.0
# Eticheta reala:5.0, eticheta prezisa:6.0
# Eticheta reala:6.0, eticheta prezisa:6.0
# Eticheta reala:6.0, eticheta prezisa:6.0
# Eticheta reala:6.0, eticheta prezisa:5.0
# Eticheta reala:6.0, eticheta prezisa:6.0
# Eticheta reala:5.0, eticheta prezisa:5.0
# Eticheta reala:5.0, eticheta prezisa:6.0
# Eticheta reala:5.0, eticheta prezisa:5.0
# Eticheta reala:6.0, eticheta prezisa:6.0
# Eticheta reala:3.0, eticheta prezisa:5.0
# ...
